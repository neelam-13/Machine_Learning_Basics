# %% [markdown]
# # Exercise 1: PCA, ICA and Sparse Coding

# %% [markdown]
# ## Preamble
# The following code downloads and imports all necessary files and modules into the virtual machine of Colab. Please make sure to execute it before solving this exercise.

# %%
import sys, os
if 'google.colab' in sys.modules:
  if os.getcwd() == '/content':
    # !git clone 'https://github.com/inb-uni-luebeck/cs5450.git'
    os.chdir('cs5450')
# Out:
# Cloning into 'cs5450'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 16 (delta 4), reused 16 (delta 4), pack-reused 0
# Unpacking objects: 100% (16/16), done.

# %% [markdown]
# ## Exercise 1.1: Applying unsupervised methods
#
# In this exercise, we will apply three unsupervised methods, namely *Prinicipal Component Analysis (PCA)*, *Independent Component Analysis (ICA)*, and *Sparse Coding (SC)* to image patches taken from handwritting digits and from faces.
#
# Since implementing [ICA](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.FastICA.html) and [SC](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.SparseCoder.html) is rather complex, we will use already existing python packages.
#
# We will build on the python starter code given below. You only need to write code at the places indicated by `TODO`.
# The two given datasets are `mnist.npz` for handwritten digits and `olivetti.npz` for faces. Each dataset contains a multi dimensional array `data` with the first index corresponding to the observations and the second index corresponding to the features (grayscale pixels). Both datasets contain square-shaped images.
#
# Implement the missing parts below. When done correctly, your code should do the following:
# 1. Load the dataset with either handwritten images or faces.
# 2. Enforce mean-free observations by subtracting the mean from the data.
# 3. Randomly draw square-shaped image patches from the data.
# 4. Apply one of the three unsupervised methods (PCA, ICA, or SC).
# 5. Show the resulting set of new basis vectors (i.e. the components for PCA and ICA).
# 6. Reconstruct the original image patches with different subsets of basis vectors.
#
# In case you are struggeling with the task, here are some helpful tips and hints:
# 1. Useful functions: [`numpy.load`](https://docs.scipy.org/doc/numpy/reference/generated/numpy.load.html), [`ndarray.astype`](https://docs.scipy.org/doc/numpy/reference/generated/numpy.ndarray.astype.html), [`numpy.mean`](https://docs.scipy.org/doc/numpy/reference/generated/numpy.mean.html), [`numpy.linalg.pinv`](https://docs.scipy.org/doc/numpy/reference/generated/numpy.linalg.pinv.html), [`numpy.matmul`](https://docs.scipy.org/doc/numpy/reference/generated/numpy.matmul.html), [`numpy.stack`](https://docs.scipy.org/doc/numpy/reference/generated/numpy.stack.html), `random_patches`, `show_in_grid`, [`PCA`](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html), [`FastICA`](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.FastICA.html#sklearn.decomposition.FastICA), [`DictionaryLearning`](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.DictionaryLearning.html#sklearn.decomposition.DictionaryLearning)
# 2. You should start with both PCA and ICA and only then use SC.
# 3. Applying SC may take a couple of minutes. Good initial value for it are:
#  - `dataset='mnist'`
#  - `n_patches=10000`
#  - `patch_size=25`
#  - `n_basis=100`
#  - `n_iterations=50`
#  - and instantiate the class with `n_jobs=-1` to utilize all CPU cores, as well as `verbose=True` to see progress feedback

# %% [markdown]
# Import and helper functions. Do not change!

# %%
import numpy as np
import math
import random
from sklearn.decomposition import PCA, FastICA, DictionaryLearning
from matplotlib import pyplot as plt
# %matplotlib inline

def random_patches(data, img_height, img_width, n_patches, patch_size):
    # RANDOMPATCHES draw random square-shaped patches from the data.
    #
    # INPUT:
    #   data : ndarray containing the data (i.e. mnist or olivetti)
    #   img_height : height of the images
    #   img_width : width of the images
    #   n_patches : number of patches to be drawn
    #   patch_size : size (both width and height) of the square-shaped patches
    #
    # OUTPUT:
    #   patches : random patches

    # reshape data 2d -> 3d
    n_images = data.shape[0]
    data = data.reshape(n_images, img_height, img_width)

    # extract random patches
    patches = []#np.zeros((n_patches, patch_size*patch_size))
    for i in range(n_patches):
        patch_top = random.randint(0, img_height - patch_size)
        patch_left = random.randint(0, img_width - patch_size)
        p = data[random.randint(0, n_images-1), patch_top:patch_top+patch_size, patch_left:patch_left+patch_size]
        patches.append(p)
        #patches[i,:] = p[:]
        
    patches = np.stack(patches)
    patches = patches.reshape(patches.shape[0], -1) #flatten each patch
        
    return patches

def show_in_grid(images, height, width):
    # flatten images if necessary
    images = images.reshape(images.shape[0], -1)
    
    # normalize patches
    images = images / (np.abs(images).max(axis=1, keepdims=True)+1e-6)
    
    # reshape into images
    images = images.reshape(-1, height, width)
    
    # make images fit into a rectangular area
    grid_width = math.ceil(math.sqrt(images.shape[0]))
    grid_height = math.ceil(images.shape[0] / grid_width)
    
    empty_cells = grid_width * grid_height - images.shape[0]
    
    # fill empty cells
    if empty_cells > 0:
        padding = np.zeros((empty_cells, height, width))
        images = np.concatenate((images, padding))
        
    # rearrange basis into grid and also switch width and height so x and y axis are not switched
    images = images.reshape(grid_height, grid_width, height, width)
    images = images.transpose(0, 3, 1, 2)
    
    plt.figure(figsize = (10,10))
    plt.imshow(images.reshape(grid_height*height, grid_width*width), cmap='gray')
    plt.show()

# %% [markdown]
# Your solution:

# %%
## Define variables

# TODO dataset : relative path to the .npz file containing the data
dataset = 'data/mnist.npz' #'data/olivetti.npz' 

# TODO n_patches : number of random patches to extract from the images
n_patches = 10000
# TODO patch_size : size (both width and height) of the square-shaped patches
patch_size = 25

# TODO n_basis : number of new basis vectors
n_basis = 100

# TODO method : string describing whether to perform pca, ica, or sc
method = 'ica'

# TODO n_iterations : number of iterations (only for sparse coding)
n_iterations = 50

# %%
## Compute and show the principal components

# TODO load dataset
with np.load(dataset) as file:
    data = file['data']

# TODO convert data to floating point (double precision)
#print(type(data))
data = data.astype(float)
#print(data[0][0])

# TODO get number of images (observations) and number of pixels (features)
n_images, n_pixels = data.shape
print(data.shape)

# TODO get height and width of the images
img_height = int(math.sqrt(n_pixels))
img_width = img_height

assert isinstance(img_height, int) and isinstance(img_width, int), "Image dimensions need to be integers."

# TODO enforce mean-free data vectors
print(np.mean(data, axis=0).shape)
mean_free_data = data - np.mean(data, axis=0)
#print(data)

# TODO draw random patches from data.
patches = random_patches(mean_free_data, img_height, img_width, n_patches, patch_size)
#print(type(patches))
#show_in_grid(patches[:10], patch_size, patch_size)

# TODO perform the chosen unsupervised method on the drawn patches
if method == 'pca':
    pca = PCA()
    pca.fit(patches)
    basis = pca.components_
    #print(basis)
elif method == 'ica':
    ica = FastICA(n_components = n_basis)
    ica.fit(patches)
    basis = ica.components_
elif method == 'sc':
    sc = DictionaryLearning(n_jobs=-1,verbose=True, n_components = n_basis)
    sc.fit(patches)
    basis = sc.components_

# TODO show the new set of basis vectors (only the first n_basis)
#show_in_grid(np.array([patch*basis for patch in patches[:10]]), patch_size, patch_size)
show_in_grid(basis[:n_basis], patch_size, patch_size)
# Out:
# (70000, 784)
# (784,)
# <class 'numpy.ndarray'>

# %%
## Use different subsets of the new basis vectors to reconstruct a random patch
from sklearn.decomposition import sparse_encode

# TODO draw a random patch
random_patch = random_patches(data=data, img_height=img_height, img_width=img_width, n_patches=1, patch_size=patch_size)
show_in_grid(random_patch, patch_size, patch_size)
#random_patch = random_patch * basis
#show_in_grid(random_patch, patch_size, patch_size)
#print(basis)
print(random_patch.shape)
#random_patch = random_patch.reshape(-1)

# TODO reconstruct the random patch
reconstructions = []
for i in range(n_basis):
    sub_basis = basis[0:i+1]
    #print("sub_basis: {}".format(sub_basis.shape))
    random_patch_transformed = np.matmul(sub_basis, random_patch.transpose())
    #print("random patch after transformation: {}".format(random_patch_transformed.shape))
    sub_basis_inverse = np.linalg.pinv(sub_basis)
    #print("sub basis inverse: {}".format(sub_basis_inverse.shape))
    
    if method == 'sc':
        pass
    else:
        reconstructions.append(np.matmul(sub_basis_inverse, random_patch_transformed))
    
reconstructions = np.stack(reconstructions)

# TODO show the reconstructed patch
show_in_grid(reconstructions, patch_size, patch_size)
# Out:
# (1, 625)
# sub_basis: (1, 625)
# random patch after transformation: (1, 1)
# sub basis inverse: (625, 1)
# sub_basis: (2, 625)
# random patch after transformation: (2, 1)
# sub basis inverse: (625, 2)
# sub_basis: (3, 625)
# random patch after transformation: (3, 1)
# sub basis inverse: (625, 3)
# sub_basis: (4, 625)
# random patch after transformation: (4, 1)
# sub basis inverse: (625, 4)
# sub_basis: (5, 625)
# random patch after transformation: (5, 1)
# sub basis inverse: (625, 5)
# sub_basis: (6, 625)
# random patch after transformation: (6, 1)
# sub basis inverse: (625, 6)
# sub_basis: (7, 625)
# random patch after transformation: (7, 1)
# sub basis inverse: (625, 7)
# sub_basis: (8, 625)
# random patch after transformation: (8, 1)
# sub basis inverse: (625, 8)
# sub_basis: (9, 625)
# random patch after transformation: (9, 1)
# sub basis inverse: (625, 9)
# sub_basis: (10, 625)
# random patch after transformation: (10, 1)
# sub basis inverse: (625, 10)
# sub_basis: (11, 625)
# random patch after transformation: (11, 1)
# sub basis inverse: (625, 11)
# sub_basis: (12, 625)
# random patch after transformation: (12, 1)
# sub basis inverse: (625, 12)
# sub_basis: (13, 625)
# random patch after transformation: (13, 1)
# sub basis inverse: (625, 13)
# sub_basis: (14, 625)
# random patch after transformation: (14, 1)
# sub basis inverse: (625, 14)
# sub_basis: (15, 625)
# random patch after transformation: (15, 1)
# sub basis inverse: (625, 15)
# sub_basis: (16, 625)
# random patch after transformation: (16, 1)
# sub basis inverse: (625, 16)
# sub_basis: (17, 625)
# random patch after transformation: (17, 1)
# sub basis inverse: (625, 17)
# sub_basis: (18, 625)
# random patch after transformation: (18, 1)
# sub basis inverse: (625, 18)
# sub_basis: (19, 625)
# random patch after transformation: (19, 1)
# sub basis inverse: (625, 19)
# sub_basis: (20, 625)
# random patch after transformation: (20, 1)
# sub basis inverse: (625, 20)
# sub_basis: (21, 625)
# random patch after transformation: (21, 1)
# sub basis inverse: (625, 21)
# sub_basis: (22, 625)
# random patch after transformation: (22, 1)
# sub basis inverse: (625, 22)
# sub_basis: (23, 625)
# random patch after transformation: (23, 1)
# sub basis inverse: (625, 23)
# sub_basis: (24, 625)
# random patch after transformation: (24, 1)
# sub basis inverse: (625, 24)
# sub_basis: (25, 625)
# random patch after transformation: (25, 1)
# sub basis inverse: (625, 25)
# sub_basis: (26, 625)
# random patch after transformation: (26, 1)
# sub basis inverse: (625, 26)
# sub_basis: (27, 625)
# random patch after transformation: (27, 1)
# sub basis inverse: (625, 27)
# sub_basis: (28, 625)
# random patch after transformation: (28, 1)
# sub basis inverse: (625, 28)
# sub_basis: (29, 625)
# random patch after transformation: (29, 1)
# sub basis inverse: (625, 29)
# sub_basis: (30, 625)
# random patch after transformation: (30, 1)
# sub basis inverse: (625, 30)
# sub_basis: (31, 625)
# random patch after transformation: (31, 1)
# sub basis inverse: (625, 31)
# sub_basis: (32, 625)
# random patch after transformation: (32, 1)
# sub basis inverse: (625, 32)
# sub_basis: (33, 625)
# random patch after transformation: (33, 1)
# sub basis inverse: (625, 33)
# sub_basis: (34, 625)
# random patch after transformation: (34, 1)
# sub basis inverse: (625, 34)
# sub_basis: (35, 625)
# random patch after transformation: (35, 1)
# sub basis inverse: (625, 35)
# sub_basis: (36, 625)
# random patch after transformation: (36, 1)
# sub basis inverse: (625, 36)
# sub_basis: (37, 625)
# random patch after transformation: (37, 1)
# sub basis inverse: (625, 37)
# sub_basis: (38, 625)
# random patch after transformation: (38, 1)
# sub basis inverse: (625, 38)
# sub_basis: (39, 625)
# random patch after transformation: (39, 1)
# sub basis inverse: (625, 39)
# sub_basis: (40, 625)
# random patch after transformation: (40, 1)
# sub basis inverse: (625, 40)
# sub_basis: (41, 625)
# random patch after transformation: (41, 1)
# sub basis inverse: (625, 41)
# sub_basis: (42, 625)
# random patch after transformation: (42, 1)
# sub basis inverse: (625, 42)
# sub_basis: (43, 625)
# random patch after transformation: (43, 1)
# sub basis inverse: (625, 43)
# sub_basis: (44, 625)
# random patch after transformation: (44, 1)
# sub basis inverse: (625, 44)
# sub_basis: (45, 625)
# random patch after transformation: (45, 1)
# sub basis inverse: (625, 45)
# sub_basis: (46, 625)
# random patch after transformation: (46, 1)
# sub basis inverse: (625, 46)
# sub_basis: (47, 625)
# random patch after transformation: (47, 1)
# sub basis inverse: (625, 47)
# sub_basis: (48, 625)
# random patch after transformation: (48, 1)
# sub basis inverse: (625, 48)
# sub_basis: (49, 625)
# random patch after transformation: (49, 1)
# sub basis inverse: (625, 49)
# sub_basis: (50, 625)
# random patch after transformation: (50, 1)
# sub basis inverse: (625, 50)
# sub_basis: (51, 625)
# random patch after transformation: (51, 1)
# sub basis inverse: (625, 51)
# sub_basis: (52, 625)
# random patch after transformation: (52, 1)
# sub basis inverse: (625, 52)
# sub_basis: (53, 625)
# random patch after transformation: (53, 1)
# sub basis inverse: (625, 53)
# sub_basis: (54, 625)
# random patch after transformation: (54, 1)
# sub basis inverse: (625, 54)
# sub_basis: (55, 625)
# random patch after transformation: (55, 1)
# sub basis inverse: (625, 55)
# sub_basis: (56, 625)
# random patch after transformation: (56, 1)
# sub basis inverse: (625, 56)
# sub_basis: (57, 625)
# random patch after transformation: (57, 1)
# sub basis inverse: (625, 57)
# sub_basis: (58, 625)
# random patch after transformation: (58, 1)
# sub basis inverse: (625, 58)
# sub_basis: (59, 625)
# random patch after transformation: (59, 1)
# sub basis inverse: (625, 59)
# sub_basis: (60, 625)
# random patch after transformation: (60, 1)
# sub basis inverse: (625, 60)
# sub_basis: (61, 625)
# random patch after transformation: (61, 1)
# sub basis inverse: (625, 61)
# sub_basis: (62, 625)
# random patch after transformation: (62, 1)
# sub basis inverse: (625, 62)
# sub_basis: (63, 625)
# random patch after transformation: (63, 1)
# sub basis inverse: (625, 63)
# sub_basis: (64, 625)
# random patch after transformation: (64, 1)
# sub basis inverse: (625, 64)
# sub_basis: (65, 625)
# random patch after transformation: (65, 1)
# sub basis inverse: (625, 65)
# sub_basis: (66, 625)
# random patch after transformation: (66, 1)
# sub basis inverse: (625, 66)
# sub_basis: (67, 625)
# random patch after transformation: (67, 1)
# sub basis inverse: (625, 67)
# sub_basis: (68, 625)
# random patch after transformation: (68, 1)
# sub basis inverse: (625, 68)
# sub_basis: (69, 625)
# random patch after transformation: (69, 1)
# sub basis inverse: (625, 69)
# sub_basis: (70, 625)
# random patch after transformation: (70, 1)
# sub basis inverse: (625, 70)
# sub_basis: (71, 625)
# random patch after transformation: (71, 1)
# sub basis inverse: (625, 71)
# sub_basis: (72, 625)
# random patch after transformation: (72, 1)
# sub basis inverse: (625, 72)
# sub_basis: (73, 625)
# random patch after transformation: (73, 1)
# sub basis inverse: (625, 73)
# sub_basis: (74, 625)
# random patch after transformation: (74, 1)
# sub basis inverse: (625, 74)
# sub_basis: (75, 625)
# random patch after transformation: (75, 1)
# sub basis inverse: (625, 75)
# sub_basis: (76, 625)
# random patch after transformation: (76, 1)
# sub basis inverse: (625, 76)
# sub_basis: (77, 625)
# random patch after transformation: (77, 1)
# sub basis inverse: (625, 77)
# sub_basis: (78, 625)
# random patch after transformation: (78, 1)
# sub basis inverse: (625, 78)
# sub_basis: (79, 625)
# random patch after transformation: (79, 1)
# sub basis inverse: (625, 79)
# sub_basis: (80, 625)
# random patch after transformation: (80, 1)
# sub basis inverse: (625, 80)
# sub_basis: (81, 625)
# random patch after transformation: (81, 1)
# sub basis inverse: (625, 81)
# sub_basis: (82, 625)
# random patch after transformation: (82, 1)
# sub basis inverse: (625, 82)
# sub_basis: (83, 625)
# random patch after transformation: (83, 1)
# sub basis inverse: (625, 83)
# sub_basis: (84, 625)
# random patch after transformation: (84, 1)
# sub basis inverse: (625, 84)
# sub_basis: (85, 625)
# random patch after transformation: (85, 1)
# sub basis inverse: (625, 85)
# sub_basis: (86, 625)
# random patch after transformation: (86, 1)
# sub basis inverse: (625, 86)
# sub_basis: (87, 625)
# random patch after transformation: (87, 1)
# sub basis inverse: (625, 87)
# sub_basis: (88, 625)
# random patch after transformation: (88, 1)
# sub basis inverse: (625, 88)
# sub_basis: (89, 625)
# random patch after transformation: (89, 1)
# sub basis inverse: (625, 89)
# sub_basis: (90, 625)
# random patch after transformation: (90, 1)
# sub basis inverse: (625, 90)
# sub_basis: (91, 625)
# random patch after transformation: (91, 1)
# sub basis inverse: (625, 91)
# sub_basis: (92, 625)
# random patch after transformation: (92, 1)
# sub basis inverse: (625, 92)
# sub_basis: (93, 625)
# random patch after transformation: (93, 1)
# sub basis inverse: (625, 93)
# sub_basis: (94, 625)
# random patch after transformation: (94, 1)
# sub basis inverse: (625, 94)
# sub_basis: (95, 625)
# random patch after transformation: (95, 1)
# sub basis inverse: (625, 95)
# sub_basis: (96, 625)
# random patch after transformation: (96, 1)
# sub basis inverse: (625, 96)
# sub_basis: (97, 625)
# random patch after transformation: (97, 1)
# sub basis inverse: (625, 97)
# sub_basis: (98, 625)
# random patch after transformation: (98, 1)
# sub basis inverse: (625, 98)
# sub_basis: (99, 625)
# random patch after transformation: (99, 1)
# sub basis inverse: (625, 99)
# sub_basis: (100, 625)
# random patch after transformation: (100, 1)
# sub basis inverse: (625, 100)

# %% [markdown]
# *Bonus*: Implement the missing parts in the bonus section. When done correctly, your code additionally should do the following:
# 1. Perform ZCA whitening, whereas $\vec{x}_{ZCAwhite}=U\vec{x}_{wht}$ (c.f. equation 1.3 in the lecture notes).
# 2. Visualize the whitened data.

# %%
#% TODO epsilon : avoid negative numbers while computing stdDeviations
epsilon = 0.1

# TODO perform principal component analysis (help pca)
basis = -1 #get basis vector components

# TODO compute the covariance matrix of the patches
covariance = -1

# TODO compute diagonal matrix S containing the standard deviations (c.f. page 6)
std_deviations = -1

# TODO pca whitening (c.f. equation 1.3)
xPCAwhite = -1

# TODO zca whitening
xZCAwhite = -1

# TODO visualize the whitened data
# show_in_grid(xZCAwhite[:n_basis], patch_size, patch_size)

# %% [markdown]
# ## Exercise 1.2: Comprehension Questions
#
# Answer the following comprehension questions either with *right* or *wrong* and briefly explain your decision:
# 1. Regardless of the used method for representation learning (i.e. PCA, ICA, SC), the resulting set of basis vectors depends on the given dataset.

# %% [markdown]
# Yes, because the basis vectors are calculated on the given dataset.

# %% [markdown]
# 2. The first principal component has the smallest eigenvalue and covers the largest possible variance of the data.

# %% [markdown]
# No, the first principal component has an large eigenvalue and covers a large variance.

# %% [markdown]
# 3. The optimal number of principal components to retain is 42.

# %% [markdown]
# No, because their are datasets that have less dimensions and there also a dimensional reduction is the target.

# %% [markdown]
# 4. After whitening, the features of an observation are uncorrelated and have unit variance.

# %% [markdown]
# No, after the whithing all observations of one feature are uncorrelated and have unit variance.

# %% [markdown]
# 5. The resulting basis vectors of the ICA (i.e. the independent components) are mutually orthogonal.

# %% [markdown]
# No, because the basis vectors depend on the given dataset and orthogonal vectors would occur random and not in standard.

# %% [markdown]
# 6. The ICA is an enhancement of the PCA which additionally makes the already uncorrelated features statistically independent.

# %% [markdown]
# Yes, because in the PCA the features aren't statictically independent and this drawback is solved by applying whithing.

# %% [markdown]
# 7. The set of basis vectors of the ICA can be over-complete, i.e. more basis vectors than dimensions of the input space.

# %% [markdown]
# Yes, because if their are multiple linear supspaces it could generate more basis vectors than there were dimensions in the beginning.

# %% [markdown]
# 8. Sparsity means that only a few basis vectors are used to reconstruct an image.

# %% [markdown]
# No, sparsity means that information is shown with a very low amount of ones in the data.

# %% [markdown]
# 9. The optimization problem for SC (c.f. equation 1.9 in the lecture notes) is convex.

# %% [markdown]
# [Your answer]

# %% [markdown]
# 10. Unlike PCA and ICA, SC results in a linear transform of the data.

# %% [markdown]
# No, PCA and ICA produce lenear transformation of the data. Sparse coding does not do that because it is an optimization and not a projection.
